# %% [markdown]
# # Используемые библиотеки

# %%
import gc # сборщик мусора

import matplotlib.pyplot as plt
import matplotlib.image as img
import seaborn as sns
# %matplotlib inline
import numpy as np 
import pandas as pd 

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error as mse, r2_score as r2

from lightgbm import LGBMRegressor

#https://www.kaggle.com/camnugent/geospatial-feature-engineering-and-visualization

# %%
pip install lightgbm
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting lightgbm
# WARNING: You are using pip version 19.2.3, however version 20.2.4 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
#   Downloading https://files.pythonhosted.org/packages/54/1d/8ca39f006ff5e4687742824c95799bff8e3c5d73046b561da6b46b3eb5d2/lightgbm-3.1.0-py2.py3-none-win_amd64.whl (751kB)
# Requirement already satisfied: numpy in c:\users\1\appdata\local\programs\python\python38\lib\site-packages (from lightgbm) (1.18.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\1\appdata\local\programs\python\python38\lib\site-packages (from lightgbm) (0.23.2)
# Requirement already satisfied: scipy in c:\users\1\appdata\local\programs\python\python38\lib\site-packages (from lightgbm) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\1\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\1\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (0.16.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.1.0

# %% [markdown]
# 1) Выгрузка данных
# 2) Работа с данными
# 3) Обучение и тренировка
# 4) Обучение финальной модели

# %% [markdown]
# # Функции, используемые в коде

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
#                 if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
#                     df[col] = df[col].astype(np.float16)
#                 elif

                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
def nan_analize(X):
    nan_df = (X.isna().sum() / X.shape[0]).reset_index()
    nan_df.columns=['feature', 'nan_percent']

    plt.figure(figsize=(16,4))
    sns.barplot(nan_df['feature'], nan_df['nan_percent'])
    plt.title('Percent Missing')
    plt.ylabel('Missing', fontsize=12)
    plt.xlabel('Features', fontsize=12)
    plt.xticks(rotation=90)
    plt.show()

# %%
def evaluate_preds(true_values, pred_values, save=False):
    """Оценка качества модели и график preds vs true"""
    
    print("R2:\t" + str(round(r2(true_values, pred_values), 5)) + "\n" +
          "RMSE:\t" + str(round(np.sqrt(mse(true_values, pred_values)), 3)) + "\n" +
          "MSE:\t" + str(round(mse(true_values, pred_values), 3))
         )
    
    plt.figure(figsize=(8,8))
    
    sns.scatterplot(x=pred_values, y=true_values)
    plt.plot([0, 500000], [0, 500000], linestyle='--', color='black')  # диагональ, где true_values = pred_values
    
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('True vs Predicted values')
    
    if save == True:
        plt.savefig(REPORTS_FILE_PATH + 'report.png')
    plt.show()

# %%
def plot_feature_importances(importances, X):
    
    indices = np.argsort(importances)[::-1]

    plt.figure(figsize = (20, 6))
    plt.title("Feature importances", fontsize=16)
    plt.bar(range(X.shape[1]), importances[indices] / importances.sum(),
           color="darkblue", align="center")
    plt.xticks(range(X.shape[1]), X.columns[indices], rotation = 90, fontsize=14)
    plt.xlim([-1, X.shape[1]])

    plt.tight_layout()
    # plt.savefig('fe.jpg')
    plt.show()

# %% [markdown]
# # Загрузка данных

# %%
df = pd.read_csv('Data set to train.csv')
df.head(10)
# Out:
#      Id   longitude  latitude  housing_median_age  total_rooms  \
# 0   5088    -118.28     33.98                19.0        883.0
# 1  17096    -122.23     37.46                33.0       2643.0
# 2   5617    -118.26     33.79                42.0       1162.0
# 3  20060    -119.26     35.87                24.0       1590.0
# 4    895    -121.96     37.54                14.0       5106.0
# 5  19653    -120.85     37.49                39.0       2840.0
# 6  18403    -121.84     37.24                24.0       7991.0
# 7  11307    -117.94     33.78                40.0        299.0
# 8   1225    -120.43     38.25                13.0        763.0
# 9   6408    -118.03     34.13                33.0       2352.0
#
#    total_bedrooms  population  households  median_income ocean_proximity  \
# 0           313.0       726.0       277.0         0.9809       <1H OCEAN
# 1           464.0      1015.0       427.0         4.2232      NEAR OCEAN
# 2           264.0      1044.0       241.0         3.5488       <1H OCEAN
# 3           390.0      1686.0       372.0         1.6469          INLAND
# 4          1207.0      2738.0      1108.0         3.9909       <1H OCEAN
# 5           733.0      2606.0       737.0         1.9429          INLAND
# 6          1286.0      4017.0      1213.0         5.4741       <1H OCEAN
# 7            68.0       163.0        70.0         3.0125       <1H OCEAN
# 8           161.0       311.0       125.0         2.4583          INLAND
# 9           373.0       995.0       359.0         4.9583          INLAND
#
#    median_house_value
# 0            121400.0
# 1            363700.0
# 2            205600.0
# 3             47600.0
# 4            236000.0
# 5             76400.0
# 6            238800.0
# 7            166100.0
# 8            112500.0
# 9            445700.0

# %%
df.columns
# Out:
# Index(['Id ', 'longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity', 'median_house_value'],
#       dtype='object')

# %%
X = df.drop('median_house_value', axis=1)
y = df[['Id ', 'median_house_value']]

X.set_index('Id ', inplace=True)
y.set_index('Id ', inplace=True)

print('Строк в трейне:' ,  X.shape[0])
print('Строк в тесте', X_final.shape[0])

# Удалим ненужные файлы
#del df
#gc.collect()
# Out:
# Строк в трейне: 13828
# Строк в тесте 6812

# %%
X_final = pd.read_csv('Data set to test X.csv')
X_final.set_index('Id ', inplace=True)
final_index_list = X_final.index

# %%
X = reduce_mem_usage(X)
# Out:
# Memory usage of dataframe is 1.05 MB
# Memory usage after optimization is: 0.54 MB
# Decreased by 48.7%

# %%
X_final = reduce_mem_usage(X_final)
# Out:
# Memory usage of dataframe is 0.52 MB
# Memory usage after optimization is: 0.27 MB
# Decreased by 48.7%

# %% [markdown]
# # Смотрим данные (EDA)

# %% [markdown]
# **Описание датасета**
#
# Статистические данные о ряде домов в Калифорнии, основанные на переписи 1990 года.
#
# * **longitude** - долгота
# * **latitude** - широта
# * **housing_median_age** - средний возраст дома
# * **total_rooms** - общее количество комнат
# * **total_bedrooms** - общее количество спален
# * **population** - количество проживающих
# * **households** - домохозяйства
# * **ocean_proximity** - близость океана
# * **median_income** - средний доход
# * **median_house_value** - средняя стоимость дома

# %%
X.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# Id
# 5088     -118.28     33.98                19.0        883.0           313.0
# 17096    -122.23     37.46                33.0       2643.0           464.0
# 5617     -118.26     33.79                42.0       1162.0           264.0
# 20060    -119.26     35.87                24.0       1590.0           390.0
# 895      -121.96     37.54                14.0       5106.0          1207.0
#
#        population  households  median_income ocean_proximity
# Id
# 5088        726.0       277.0         0.9809       <1H OCEAN
# 17096      1015.0       427.0         4.2232      NEAR OCEAN
# 5617       1044.0       241.0         3.5488       <1H OCEAN
# 20060      1686.0       372.0         1.6469          INLAND
# 895        2738.0      1108.0         3.9909       <1H OCEAN

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13828 entries, 5088 to 15795
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           13828 non-null  float64
#  1   latitude            13828 non-null  float64
#  2   housing_median_age  13349 non-null  float64
#  3   total_rooms         13828 non-null  float64
#  4   total_bedrooms      13828 non-null  float64
#  5   population          13429 non-null  float64
#  6   households          13828 non-null  float64
#  7   median_income       13828 non-null  float64
#  8   ocean_proximity     13828 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.1+ MB

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity'],
#       dtype='object')

# %%
X.shape
# Out:
# (13828, 9)

# %%
X[['longitude', 'latitude']].head(5)
# Out:
#        longitude  latitude
# Id
# 5088     -118.28     33.98
# 17096    -122.23     37.46
# 5617     -118.26     33.79
# 20060    -119.26     35.87
# 895      -121.96     37.54

# %%
X[(X['longitude'] < 120) & (X['latitude'] < 34)].head(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# Id
# 5088     -118.28     33.98                19.0        883.0           313.0
# 5617     -118.26     33.79                42.0       1162.0           264.0
# 11307    -117.94     33.78                40.0        299.0            68.0
# 7341     -118.14     33.97                29.0       1846.0           530.0
# 15142    -116.89     32.82                18.0       2515.0           443.0
# 7731     -118.14     33.92                31.0       3731.0           853.0
# 12386    -116.39     33.69                10.0      11659.0          2007.0
# 8366     -118.35     33.97                26.0       3832.0          1074.0
# 8238     -118.18     33.77                39.0       1645.0           547.0
# 11520    -118.06     33.72                14.0       2665.0           331.0
#
#        population  households  median_income ocean_proximity
# Id
# 5088        726.0       277.0         0.9809       <1H OCEAN
# 5617       1044.0       241.0         3.5488       <1H OCEAN
# 11307       163.0        70.0         3.0125       <1H OCEAN
# 7341       2576.0       528.0         2.6300       <1H OCEAN
# 15142      1442.0       449.0         5.0201       <1H OCEAN
# 7731       2313.0       801.0         3.2237       <1H OCEAN
# 12386      2186.0      1083.0         6.9833          INLAND
# 8366       2340.0       904.0         2.6734       <1H OCEAN
# 8238       1339.0       499.0         1.5536      NEAR OCEAN
# 11520       964.0       319.0        15.0001      NEAR OCEAN

# %% [markdown]
# ## Количественные переменные

# %%
X.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  13828.000000  13828.000000        13349.000000  13828.000000
# mean    -119.489883     34.763235           28.569706   2647.567255
# std        4.857729    115.937671           12.582947   2171.663363
# min     -124.350000 -13534.030000            1.000000      2.000000
# 25%     -121.810000     33.940000           18.000000   1455.000000
# 50%     -118.510000     34.270000           29.000000   2139.000000
# 75%     -118.010000     37.720000           37.000000   3166.000000
# max      121.290000   1327.130000           52.000000  32627.000000
#
#        total_bedrooms    population    households  median_income
# count    13828.000000  13429.000000  13828.000000   13828.000000
# mean       540.267139   1430.854271    501.675441       3.876745
# std        421.248573   1148.827206    383.639299       1.903102
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    791.000000    280.000000       2.568575
# 50%        437.000000   1168.000000    412.000000       3.538750
# 75%        648.000000   1732.000000    607.000000       4.756600
# max       6445.000000  35682.000000   6082.000000      15.000100

# %%
X.hist(figsize=(16,16), bins=20);

# %%
plt.figure(figsize = (15,10))

sns.set(font_scale=1.4)

corr_matrix = X.corr()
print(X.corr())
corr_matrix = np.round(corr_matrix, 2)
corr_matrix[np.abs(corr_matrix) < 0.2] = 0  # Проверьте, что будет если убрать маленькие корреляции

sns.heatmap(corr_matrix, annot=True, linewidths=.5, cmap='coolwarm')

plt.title('Correlation matrix')
plt.show()
# Out:
#                      longitude  latitude  housing_median_age  total_bedrooms  \
# longitude             1.000000 -0.183819           -0.097868        0.061360
# latitude             -0.183819  1.000000            0.000507       -0.011244
# housing_median_age   -0.097868  0.000507            1.000000       -0.314508
# total_bedrooms        0.061360 -0.011244           -0.314508        1.000000
# population            0.089268 -0.020244           -0.281327        0.863238
# median_income        -0.019546 -0.022771           -0.112840       -0.010957
# -                    -0.002473 -0.000082           -0.007558       -0.006086
# <1H OCEAN             0.319390 -0.093150            0.044348        0.017643
# INLAND               -0.048538  0.078180           -0.237842        0.000358
# ISLAND                0.009266 -0.003166            0.017971        0.000037
# NEAR BAY             -0.474220  0.065347            0.253187       -0.017385
# NEAR OCEAN            0.041261 -0.032684            0.027046       -0.009921
# population_per_room  -0.000687  0.000245            0.025441       -0.025946
#
#                      population  median_income         -  <1H OCEAN    INLAND  \
# longitude              0.089268      -0.019546 -0.002473   0.319390 -0.048538
# latitude              -0.020244      -0.022771 -0.000082  -0.093150  0.078180
# housing_median_age    -0.281327      -0.112840 -0.007558   0.044348 -0.237842
# total_bedrooms         0.863238      -0.010957 -0.006086   0.017643  0.000358
# population             1.000000       0.002331 -0.009353   0.071463 -0.011306
# median_income          0.002331       1.000000  0.000206   0.166142 -0.234259
# -                     -0.009353       0.000206  1.000000  -0.027430 -0.021005
# <1H OCEAN              0.071463       0.166142 -0.027430   1.000000 -0.612295
# INLAND                -0.011306      -0.234259 -0.021005  -0.612295  1.000000
# ISLAND                -0.007337      -0.008382 -0.000452  -0.013172 -0.010087
# NEAR BAY              -0.060334       0.054848 -0.010907  -0.317943 -0.243471
# NEAR OCEAN            -0.032872       0.028777 -0.011493  -0.335006 -0.256537
# population_per_room    0.067105       0.000528 -0.000263   0.001069  0.007699
#
#                        ISLAND  NEAR BAY  NEAR OCEAN  population_per_room
# longitude            0.009266 -0.474220    0.041261            -0.000687
# latitude            -0.003166  0.065347   -0.032684             0.000245
# housing_median_age   0.017971  0.253187    0.027046             0.025441
# total_bedrooms       0.000037 -0.017385   -0.009921            -0.025946
# population          -0.007337 -0.060334   -0.032872             0.067105
# median_income       -0.008382  0.054848    0.028777             0.000528
# -                   -0.000452 -0.010907   -0.011493            -0.000263
# <1H OCEAN           -0.013172 -0.317943   -0.335006             0.001069
# INLAND              -0.010087 -0.243471   -0.256537             0.007699
# ISLAND               1.000000 -0.005238   -0.005519            -0.000912
# NEAR BAY            -0.005238  1.000000   -0.133210            -0.009568
# NEAR OCEAN          -0.005519 -0.133210    1.000000            -0.003283
# population_per_room -0.000912 -0.009568   -0.003283             1.000000

# %%
sns.set()
sns.pairplot(X, height = 2.5)
plt.show()

# %%
corr_with_target = df.corr().iloc[:-1, -1].sort_values(ascending=False)

plt.figure(figsize=(10, 8))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %% [markdown]
# ## Качественные переменные

# %%
X['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     6144
# INLAND        4414
# NEAR OCEAN    1702
# NEAR BAY      1552
# -               13
# ISLAND           3
# Name: ocean_proximity, dtype: int64

# %%
base_features = ['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'ocean_proximity']

# %%
plt.figure(figsize = (24, 50))

l = len(base_features)

for i in range(l):
    plt.subplot((l+1)//2,2,i+1)
    plt.title(base_features[i])
    if X[base_features[i]].dtype == 'float64':
        sns.kdeplot(X[base_features[i]], shade=True, label='train', color='r')
        sns.kdeplot(X_final[base_features[i]], shade=True, label='test', color='b')
    else:
        sns.countplot(y=base_features[i], data=X, color = 'r')
        sns.countplot(y=base_features[i], data=X_final, color = 'b')

plt.show()
#for i in range(0, 5):
#  plt.subplot(5,2,i+1)

# %% [markdown]
# # Анализируем и исправляем

# %%
nan_analize(X)

# %%
median = X['housing_median_age'].median()
X['housing_median_age'] = X['housing_median_age'].fillna(median)
X_final['housing_median_age'] = X_final['housing_median_age'].fillna(median)

# %%
median = X['population'].median()
X['population'] = X['population'].fillna(median)
X_final['population'] = X_final['population'].fillna(median)

# %%
X.loc[X['longitude'] == 0]
# Out:
#        longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# Id
# 17085        0.0  37.470001                33.0       1266.0           415.0
# 17359        0.0  34.880001                 4.0       3680.0           559.0
# 19423        0.0  37.689999                 5.0       9601.0          1639.0
#
#        population  households  median_income ocean_proximity
# Id
# 17085      1991.0       334.0         2.9200      NEAR OCEAN
# 17359      1678.0       569.0         5.0639       <1H OCEAN
# 19423      4449.0      1575.0         4.5332          INLAND

# %%
# третье
X.loc[X['longitude'] > 0, 'longitude'] = X.loc[X['longitude'] > 0, 'longitude'] * -1
X_final.loc[X_final['longitude'] > 0, 'longitude'] = X_final.loc[X_final['longitude'] > 0, 'longitude'] * -1

# %%
# четвёртое
X.loc[X['longitude'] == 0, 'longitude'] = X['longitude'].median()
X_final.loc[X_final['longitude'] == 0, 'longitude'] = X_final['longitude'].median()

# %%
# пятое
median = X['latitude'].median()
X.loc[X['latitude'] < 0, 'latitude'] = median
X_final.loc[X_final['latitude'] < 0, 'latitude'] = median

# %%
#удаляем столбцы, которые имеют наибольшую корреляционную зависимость с другими столбцами(По матрице корреляции Пирсона)

# %%
X = X.drop('total_rooms', axis=1)
X_final = X_final.drop('total_rooms', axis=1)

# %%
X = X.drop('households', axis=1)
X_final = X_final.drop('households', axis=1)

# %%
X.head()
# Out:
#         longitude   latitude  housing_median_age  total_rooms  population  \
# Id
# 5088  -118.279999  33.980000                19.0        883.0       726.0
# 17096 -122.230003  37.459999                33.0       2643.0      1015.0
# 5617  -118.260002  33.790001                42.0       1162.0      1044.0
# 20060 -119.260002  35.869999                24.0       1590.0      1686.0
# 895   -121.959999  37.540001                14.0       5106.0      2738.0
#
#        median_income ocean_proximity  -  <1H OCEAN  INLAND  ISLAND  NEAR BAY  \
# Id
# 5088          0.9809       <1H OCEAN  0          1       0       0         0
# 17096         4.2232      NEAR OCEAN  0          0       0       0         0
# 5617          3.5488       <1H OCEAN  0          1       0       0         0
# 20060         1.6469          INLAND  0          0       1       0         0
# 895           3.9909       <1H OCEAN  0          1       0       0         0
#
#        NEAR OCEAN  population_per_room
# Id
# 5088            0             0.822197
# 17096           1             0.384033
# 5617            0             0.898451
# 20060           0             1.060377
# 895             0             0.536232

# %%
# седьмое
X = pd.concat([X, pd.get_dummies(X['ocean_proximity'])], axis=1)
X_final = pd.concat([X_final, pd.get_dummies(X_final['ocean_proximity'])], axis=1)

# %%
X.head()
# Out:
#         longitude   latitude  housing_median_age  population  total_rooms  \
# Id
# 5088  -118.279999  33.980000                19.0       726.0        883.0
# 17096 -122.230003  37.459999                33.0      1015.0       2643.0
# 5617  -118.260002  33.790001                42.0      1044.0       1162.0
# 20060 -119.260002  35.869999                24.0      1686.0       1590.0
# 895   -121.959999  37.540001                14.0      2738.0       5106.0
#
#        median_income  population_per_room  -  <1H OCEAN  INLAND  ISLAND  \
# Id
# 5088          0.9809             0.822197  0          1       0       0
# 17096         4.2232             0.384033  0          0       0       0
# 5617          3.5488             0.898451  0          1       0       0
# 20060         1.6469             1.060377  0          0       1       0
# 895           3.9909             0.536232  0          1       0       0
#
#        NEAR BAY  NEAR OCEAN
# Id
# 5088          0           0
# 17096         0           1
# 5617          0           0
# 20060         0           0
# 895           0           0

# %%
# шестое
X['population_per_room'] = X['population'] / X['total_rooms']
X_final['population_per_room'] = X_final['population'] / X_final['total_rooms']

# %%
#a = np.array(X['population_per_room'])

# %%
#np.percentile(a, 99)
# Out:
# 1.590177626609802

# %%
#X[X['population_per_room'] > 1.59].count()
# Out:
# longitude              139
# latitude               139
# housing_median_age     139
# total_rooms            139
# total_bedrooms         139
# population             139
# households             139
# median_income          139
# ocean_proximity        139
# -                      139
# <1H OCEAN              139
# INLAND                 139
# ISLAND                 139
# NEAR BAY               139
# NEAR OCEAN             139
# population_per_room    139
# dtype: int64

# %%
#median = X[X['population_per_room'] <= 1.59].median()

# %%
#X['population_per_room'].replace(X[X['population_per_room'] > 5], median)
# Out:
# Id
# 5088     0.822197
# 17096    0.384033
# 5617     0.898451
# 20060    1.060377
# 895      0.536232
#            ...
# 11284    0.494737
# 11964    0.568418
# 5390     0.835792
# 860      0.497063
# 15795    0.619735
# Name: population_per_room, Length: 13828, dtype: float32

# %%
X['population_per_room'].head()
# Out:
# Id
# 5088     0.822197
# 17096    0.384033
# 5617     0.898451
# 20060    1.060377
# 895      0.536232
# Name: population_per_room, dtype: float32

# %%
X['population_per_room'].describe()
# Out:
# count    13828.000000
# mean         0.637029
# std          3.532488
# min          0.019218
# 25%          0.433649
# 50%          0.516548
# 75%          0.658146
# max        392.631592
# Name: population_per_room, dtype: float64

# %%
X.loc[X['total_bedrooms'] + 1 > X['total_rooms'] ].head(20)
# Out:
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# Id
# 3126  -117.790001  35.209999                 4.0          2.0             2.0
# 19435 -121.040001  37.669998                16.0         19.0            19.0
#
#        population  households  median_income ocean_proximity  -  <1H OCEAN  \
# Id
# 3126          6.0         2.0          2.375          INLAND  0          0
# 19435       166.0         9.0          0.536          INLAND  0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# Id
# 3126        1       0         0           0
# 19435       1       0         0           0

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'ocean_proximity', '-',
#        '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN',
#        'population_per_room'],
#       dtype='object')

# %% [markdown]
# # Проверяем модель

# %%
remain_features = ['longitude', 'latitude', 'housing_median_age', 'population',
         'total_bedrooms' , 'median_income', 'population_per_room', '-', '<1H OCEAN', 'INLAND', 'ISLAND',
        'NEAR BAY', 'NEAR OCEAN']

X = X[remain_features]
X_final = X_final[remain_features]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LGBMRegressor(max_depth=18,
                             min_samples_leaf=5,
                             n_estimators=250,
                             random_state=42)
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Unknown parameter: min_samples_leaf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# LGBMRegressor(max_depth=18, min_samples_leaf=5, n_estimators=250,
#               random_state=42)

# %%
y_pred_test = model.predict(X_test)
#y_test.columns
evaluate_preds(y_test['median_house_value'], y_pred_test)
# Out:
# R2:	0.836
# RMSE:	46547.806
# MSE:	2166698227.193

# %%
#0.82006
#0.81915
#0.81979
#0.82164
#0.82137'
#0.82077
#0.82667
#0.82865
#0.83112
#iam 0.83327
#0.83325
#0.83328 0.83371 0.83435 0.83462 0.836

# %%
plot_feature_importances(importances = model.feature_importances_, X=X)

# %% [markdown]
# ## Учим финальную модель

# %%
model_lgbm_f = LGBMRegressor(max_depth=18,
                             min_samples_leaf=5,
                             n_estimators=250,
                             random_state=42)
model_lgbm_f.fit(X, y)
# Out:
# [LightGBM] [Warning] Unknown parameter: min_samples_leaf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# LGBMRegressor(max_depth=18, min_samples_leaf=5, n_estimators=250,
#               random_state=42)

# %%
y_pred_test = model_lgbm_f.predict(X_final)
y_pred_test
# Out:
# array([ 78992.84091753, 114541.37479821, 485153.60419003, ...,
#        123127.48095895, 131869.08954421, 315199.00864012])

# %%
y_pred_df = pd.DataFrame(y_pred_test, columns=['median_house_value'])

# %%
y_pred_df
# Out:
#       median_house_value
# 0           78992.840918
# 1          114541.374798
# 2          485153.604190
# 3          378431.719942
# 4          293697.626030
# ...                  ...
# 6807       175543.712369
# 6808       116605.269011
# 6809       123127.480959
# 6810       131869.089544
# 6811       315199.008640
#
# [6812 rows x 1 columns]

# %%
X_final.index
# Out:
# Int64Index([20046,  3024, 15663, 20484,  9814, 13311,  7113,  7668, 18246,
#              5723,
#             ...
#              6557,  3383, 16201, 18186,  3592, 15316, 14772, 12870, 13476,
#             16123],
#            dtype='int64', name='Id ', length=6812)

# %%
filename = 'yymmdd_Surn_1.csv'
y_pred_df.to_csv(filename, index=None)

# %% [markdown]
# ## Домашнее задание
# Получить большую точность на тестовых данных.
# yymmdd_Surn_#.csv
# +ноутбук
